# %% [markdown]
# Nombrar la aplicación que lleva más tiempo sin ser actualizada.

# %% [markdown]
# # Cargo el csv y hago ajustes necesarios.

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# Cargo el csv y salto la línea 10474 (que es el index 10472 y row 10473 al cargarlo) porque está parseada mal.

# %%
play_store = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/googleplaystore.csv", skiprows = [10473])

# %% [markdown]
# Cambio el tipo object de Last Updated a tipo date.

# %%
play_store["Last Updated"] = pd.to_datetime(play_store["Last Updated"])

# %%
play_store
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  datetime64[ns]
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(10)
# memory usage: 1.1+ MB

# %% [markdown]
# # Comienzo del ejercicio.

# %% [markdown]
# Muestro los resultados en cada celda para la revisión y sé que no es necesario.

# %% [markdown]
# Busco la fecha mínima.

# %%
ultima_fecha = play_store["Last Updated"].min()
ultima_fecha
# Out:
# Timestamp('2010-05-21 00:00:00')

# %% [markdown]
# La app que lleva más tiempo sin ser actualizada es:

# %%
play_store.loc[play_store["Last Updated"] == ultima_fecha]
# Out:
#                             App Category  Rating  Reviews  Size  Installs  \
# 7479  FML F*ck my life + widget   FAMILY     4.2     1415  209k  100,000+
#
#       Type Price Content Rating         Genres Last Updated Current Ver  \
# 7479  Free     0       Everyone  Entertainment   2010-05-21         3.1
#
#      Android Ver
# 7479  1.5 and up
